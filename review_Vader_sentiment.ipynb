# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('dataset/combined_output_only_review.csv')
df = df['review']

# %%
reviews = []
for i in df:
  i = i.replace('\\n','\n').replace('\ n','\ N')
  j = i.split('\ N')
  for review in j:
    if review != ' ':
      reviews.append(review)
print(len(reviews))
# Out:
# 9226

# %% [markdown]
# Vader

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/myeongseop.kim/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from afinn import Afinn
from nltk.sentiment.vader import SentimentIntensityAnalyzer

def sentiment_vader(docs):
    analyser = SentimentIntensityAnalyzer()
    results = []

    for doc in docs:
        score = analyser.polarity_scores(doc)
        if score['compound'] >=0.05:
            results.append('pos')
        elif score['compound'] <= -0.05:
            results.append('neg')
        else:
            results.append('neutral')
    return results

# %%
sentiment = sentiment_vader(reviews)
sentiment
# Out:
# ['neutral',
#  'neutral',
#  'neutral',
#  'pos',
#  'pos',
#  'neutral',
#  'neutral',
#  'pos',
#  'neg',
#  'neutral',
#  'neutral',
#  'pos',
#  'neutral',
#  'neg',
#  'neutral',
#  'neg',
#  'neutral',
#  'pos',
#  'pos',
#  'pos',
#  'neutral',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neutral',
#  'neutral',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neutral',
#  'neg',
#  'neutral',
#  'pos',
#  'neg',
#  'pos',
#  'neutral',
#  'pos',
#  'neutral',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neutral',
#  'neg',
#  'pos',
#  'pos',
#  'neutral',
#  'pos',
#  'neutral',
#  'neutral',
#  'neutral',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neutral',
#  'neutral',
#  'pos',
#  'neutral',
#  'pos',
#  'neg',
#  'pos',
#  'neutral',
#  'neutral',
#  'pos',
#  'neutral',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neutral',
#  'pos',
#  'neutral',
# ...

# %%
print(sentiment.count('pos'))
print(sentiment.count('neg'))
print(sentiment.count('neutral'))
# Out:
# 3925
# 1773
# 3528

# %%
pos_df = []
neg_df = []
# pos_idx = 0
# neg_idx = 0

for n, i in enumerate(sentiment):

    if i == 'pos':
        pos_df.append(reviews[n])
        
    if i == 'neg':
        neg_df.append(reviews[n])

pos_df = pd.DataFrame({'review':pos_df})
neg_df = pd.DataFrame({'review':neg_df})
neg_df
# Out:
#                                                  review
# 0     You can see students running through National ...
# 1      convenience is moderately good.I don't know i...
# 2     The transfer with NJR can be done in other sta...
# 3      It is a very fast convenience in a short time...
# 4      are old.I know that I like the analog of Japa...
# ...                                                 ...
# 1768  I never understood whether I was angry with th...
# 1769   It is the worst station and attitude.It is a ...
# 1770                                  is a bad manner.
# 1771   The groove of the station/Musashino is not st...
# 1772   I can't help it because it's a small station,...
#
# [1773 rows x 1 columns]

# %%
pos_df.to_csv('pos_reviews.csv')
neg_df.to_csv('neg_reviews.csv')
